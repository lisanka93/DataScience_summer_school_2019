# %%
sales_data<-read.csv('sales.csv')
#sales_data

# %%
model_reg = lm(pizza~ ., data =sales_data)
model_reg<- step(model_reg)
# Out:
# Error in step(model_reg): AIC is -infinity for this model, so 'step' cannot proceed
# Traceback:
#
# 1. step(model_reg)
# 2. stop("AIC is -infinity for this model, so 'step' cannot proceed")

# %%
attach(sales_data)
library(tidyr)
library(dplyr)
# Out:
# The following objects are masked from sales_data (pos = 3):
#
#     chips, coffee, date, dessert, fruitcup, humidity, juice, pasta,
#     pizza, rainfall, soda, staff, temp, total_sales, weekday,
#     windspeed, wraps
#
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
sales_data<-mutate(sales_data,food=pizza,wraps,pasta)
detach(sales_data)

# %%
sales_data
# Out:
#     date      weekday   staff pizza wraps pasta dessert fruitcup chips juice
# 1   19-Jan-10 Tuesday    1     5    25     5     5       1       12     8
# 2   20-Jan-10 Wednesday  2     6     7     3     1       0        0     0
# 3   21-Jan-10 Thursday   2     8    14     4     1       0        0    13
# 4   22-Jan-10 Friday     2     4     5     5     3       3       20     0
# 5   23-Jan-10 Saturday  NA    NA    NA    NA    NA      NA       NA    NA
# 6   24-Jan-10 Sunday    NA    NA    NA    NA    NA      NA       NA    NA
# 7   25-Jan-10 Monday     1     3    10     8     3       2        0     5
# 8   26-Jan-10 Tuesday    2     7     5     1     5       2        4     4
# 9   27-Jan-10 Wednesday  2     6    19     6    10       2        2     5
# 10  28-Jan-10 Thursday   2     0     7     6     5       0       20     6
# 11  29-Jan-10 Friday     2     3     4     0     3       1        3     4
# 12  30-Jan-10 Saturday  NA    NA    NA    NA    NA      NA       NA    NA
# ...
